# %%
from urllib.request import urlopen, Request
import json
from dotenv import dotenv_values
import pandas as pd
from IPython.display import display, Markdown

config = dotenv_values("../.env")
config
# Out:
# OrderedDict([('GHTOKEN', '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'),
#              ('GHUSER', 'dominikb1888'),
#              ('GHORG', '23W-GBAC'),
#              ('GHURL', 'https://api.github.com'),
#              ('STARTDATE', '2023-10-01')])

# %%
headers = {
     'Authorization': f"token {config['GHTOKEN']}",
     'Accept': 'application/vnd.github.v3+json'
}

url = f"https://api.github.com/orgs/{config['GHORG']}/repos?per_page=100"
httprequest = Request(url, headers=headers)

with urlopen(httprequest) as response:
    if response.status == 200:
        data = json.loads(response.read().decode())
        names = []
        for repo in data:
            names.append(repo['name'])
    else:
        print(f"Failed to fetch repos. Status code: {response.status_code}")

authors = {}
for name in names:
    # https://api.github.com/repos/23W-GBAC/SenaDok/commits
    print(url)
    url = f"https://api.github.com/repos/23W-GBAC/{name}/commits"
    httprequest = Request(url, headers=headers)
    with urlopen(httprequest) as response:
        if response.status == 200:
            data = json.loads(response.read().decode())
            author = data[0]['author']
            if author:
                authors[author['login']] = author
        else:
            print(f"Failed to fetch commits. Status code: {response.status_code}")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[5], line 9
#       6 url = f"https://api.github.com/orgs/{config['GHORG']}/repos?per_page=100"
#       7 httprequest = Request(url, headers=headers)
# ----> 9 with urlopen(httprequest) as response:
#      10     if response.status == 200:
#      11         data = json.loads(response.read().decode())
#
# File /nix/store/dc4xnyqi2kh25f1c74dfczxw95anbhhr-python3-3.11.6/lib/python3.11/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File /nix/store/dc4xnyqi2kh25f1c74dfczxw95anbhhr-python3-3.11.6/lib/python3.11/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File /nix/store/dc4xnyqi2kh25f1c74dfczxw95anbhhr-python3-3.11.6/lib/python3.11/urllib/request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     631 # According to RFC 2616, "2xx" code indicates that the client's
#     632 # request was successfully received, understood, and accepted.
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File /nix/store/dc4xnyqi2kh25f1c74dfczxw95anbhhr-python3-3.11.6/lib/python3.11/urllib/request.py:563, in OpenerDirector.error(self, proto, *args)
#     561 if http_err:
#     562     args = (dict, 'default', 'http_error_default') + orig_args
# --> 563     return self._call_chain(*args)
#
# File /nix/store/dc4xnyqi2kh25f1c74dfczxw95anbhhr-python3-3.11.6/lib/python3.11/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File /nix/store/dc4xnyqi2kh25f1c74dfczxw95anbhhr-python3-3.11.6/lib/python3.11/urllib/request.py:643, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     642 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 401: Unauthorized

# %%
authors.keys()
df = pd.DataFrame(authors.values())
df[['login', 'avatar_url']]

# %%
authors.values()
# Out:
# dict_values([{'login': 'SenaDok', 'id': 148862726, 'node_id': 'U_kgDOCN93Bg', 'avatar_url': 'https://avatars.githubusercontent.com/u/148862726?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/SenaDok', 'html_url': 'https://github.com/SenaDok', 'followers_url': 'https://api.github.com/users/SenaDok/followers', 'following_url': 'https://api.github.com/users/SenaDok/following{/other_user}', 'gists_url': 'https://api.github.com/users/SenaDok/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/SenaDok/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/SenaDok/subscriptions', 'organizations_url': 'https://api.github.com/users/SenaDok/orgs', 'repos_url': 'https://api.github.com/users/SenaDok/repos', 'events_url': 'https://api.github.com/users/SenaDok/events{/privacy}', 'received_events_url': 'https://api.github.com/users/SenaDok/received_events', 'type': 'User', 'site_admin': False}, {'login': 'mohammadmasry', 'id': 148862917, 'node_id': 'U_kgDOCN93xQ', 'avatar_url': 'https://avatars.githubusercontent.com/u/148862917?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/mohammadmasry', 'html_url': 'https://github.com/mohammadmasry', 'followers_url': 'https://api.github.com/users/mohammadmasry/followers', 'following_url': 'https://api.github.com/users/mohammadmasry/following{/other_user}', 'gists_url': 'https://api.github.com/users/mohammadmasry/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/mohammadmasry/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/mohammadmasry/subscriptions', 'organizations_url': 'https://api.github.com/users/mohammadmasry/orgs', 'repos_url': 'https://api.github.com/users/mohammadmasry/repos', 'events_url': 'https://api.github.com/users/mohammadmasry/events{/privacy}', 'received_events_url': 'https://api.github.com/users/mohammadmasry/received_events', 'type': 'User', 'site_admin': False}, {'login': 'SuraniKrrish', 'id': 148862687, 'node_id': 'U_kgDOCN923w', 'avatar_url': 'https://avatars.githubusercontent.com/u/148862687?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/SuraniKrrish', 'html_url': 'https://github.com/SuraniKrrish', 'followers_url': 'https://api.github.com/users/SuraniKrrish/followers', 'following_url': 'https://api.github.com/users/SuraniKrrish/following{/other_user}', 'gists_url': 'https://api.github.com/users/SuraniKrrish/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/SuraniKrrish/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/SuraniKrrish/subscriptions', 'organizations_url': 'https://api.github.com/users/SuraniKrrish/orgs', 'repos_url': 'https://api.github.com/users/SuraniKrrish/repos', 'events_url': 'https://api.github.com/users/SuraniKrrish/events{/privacy}', 'received_events_url': 'https://api.github.com/users/SuraniKrrish/received_events', 'type': 'User', 'site_admin': False}, {'login': 'azukaegoo', 'id': 132351500, 'node_id': 'U_kgDOB-OGDA', 'avatar_url': 'https://avatars.githubusercontent.com/u/132351500?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/azukaegoo', 'html_url': 'https://github.com/azukaegoo', 'followers_url': 'https://api.github.com/users/azukaegoo/followers', 'following_url': 'https://api.github.com/users/azukaegoo/following{/other_user}', 'gists_url': 'https://api.github.com/users/azukaegoo/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/azukaegoo/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/azukaegoo/subscriptions', 'organizations_url': 'https://api.github.com/users/azukaegoo/orgs', 'repos_url': 'https://api.github.com/users/azukaegoo/repos', 'events_url': 'https://api.github.com/users/azukaegoo/events{/privacy}', 'received_events_url': 'https://api.github.com/users/azukaegoo/received_events', 'type': 'User', 'site_admin': False}, {'login': 'jysndabuio', 'id': 148863168, 'node_id': 'U_kgDOCN94wA', 'avatar_url': 'https://avatars.githubusercontent.com/u/1488 ...

# %%
author_data = list(authors.values())
author_data
# Out:
# [{'login': 'SenaDok',
#   'id': 148862726,
#   'node_id': 'U_kgDOCN93Bg',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/148862726?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/SenaDok',
#   'html_url': 'https://github.com/SenaDok',
#   'followers_url': 'https://api.github.com/users/SenaDok/followers',
#   'following_url': 'https://api.github.com/users/SenaDok/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/SenaDok/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/SenaDok/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/SenaDok/subscriptions',
#   'organizations_url': 'https://api.github.com/users/SenaDok/orgs',
#   'repos_url': 'https://api.github.com/users/SenaDok/repos',
#   'events_url': 'https://api.github.com/users/SenaDok/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/SenaDok/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'mohammadmasry',
#   'id': 148862917,
#   'node_id': 'U_kgDOCN93xQ',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/148862917?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/mohammadmasry',
#   'html_url': 'https://github.com/mohammadmasry',
#   'followers_url': 'https://api.github.com/users/mohammadmasry/followers',
#   'following_url': 'https://api.github.com/users/mohammadmasry/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/mohammadmasry/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/mohammadmasry/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/mohammadmasry/subscriptions',
#   'organizations_url': 'https://api.github.com/users/mohammadmasry/orgs',
#   'repos_url': 'https://api.github.com/users/mohammadmasry/repos',
#   'events_url': 'https://api.github.com/users/mohammadmasry/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/mohammadmasry/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'SuraniKrrish',
#   'id': 148862687,
#   'node_id': 'U_kgDOCN923w',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/148862687?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/SuraniKrrish',
#   'html_url': 'https://github.com/SuraniKrrish',
#   'followers_url': 'https://api.github.com/users/SuraniKrrish/followers',
#   'following_url': 'https://api.github.com/users/SuraniKrrish/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/SuraniKrrish/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/SuraniKrrish/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/SuraniKrrish/subscriptions',
#   'organizations_url': 'https://api.github.com/users/SuraniKrrish/orgs',
#   'repos_url': 'https://api.github.com/users/SuraniKrrish/repos',
#   'events_url': 'https://api.github.com/users/SuraniKrrish/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/SuraniKrrish/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'azukaegoo',
#   'id': 132351500,
#   'node_id': 'U_kgDOB-OGDA',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/132351500?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/azukaegoo',
#   'html_url': 'https://github.com/azukaegoo',
#   'followers_url': 'https://api.github.com/users/azukaegoo/followers',
#   'following_url': 'https://api.github.com/users/azukaegoo/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/azukaegoo/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/azukaegoo/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/azukaegoo/subscriptions',
#   'organizations_url': 'https://api.github.com/users/azukaegoo/orgs',
#   'repos_url': 'https://api.github.com/users/azukaegoo/repos',
#   'events_url': 'https://api.github.com/users/azukaegoo/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/azukaegoo/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'jysndabuio',
#   'id': 148863168,
#   'node_id': 'U_kgDOCN94wA',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/148863168?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/jysndabuio',
#   'html_url': 'https://github.com/jysndabuio',
#   'followers_url': 'https://api.github.com/users/jysndabuio/followers',
#   'following_url': 'https://api.github.com/users/jysndabuio/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/jysndabuio/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/jysndabuio/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/jysndabuio/subscriptions',
#   'organizations_url': 'https://api.github.com/users/jysndabuio/orgs',
#   'repos_url': 'https://api.github.com/users/jysndabuio/repos',
#   'events_url': 'https://api.github.com/users/jysndabuio/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/jysndabuio/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'Jokestevens',
#   'id': 148862801,
#   'node_id': 'U_kgDOCN93UQ',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/148862801?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Jokestevens',
#   'html_url': 'https://github.com/Jokestevens',
#   'followers_url': 'https://api.github.com/users/Jokestevens/followers',
#   'following_url': 'https://api.github.com/users/Jokestevens/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/Jokestevens/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/Jokestevens/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/Jokestevens/subscriptions',
#   'organizations_url': 'https://api.github.com/users/Jokestevens/orgs',
#   'repos_url': 'https://api.github.com/users/Jokestevens/repos',
#   'events_url': 'https://api.github.com/users/Jokestevens/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/Jokestevens/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'NastLen',
#   'id': 148862793,
#   'node_id': 'U_kgDOCN93SQ',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/148862793?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/NastLen',
#   'html_url': 'https://github.com/NastLen',
#   'followers_url': 'https://api.github.com/users/NastLen/followers',
#   'following_url': 'https://api.github.com/users/NastLen/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/NastLen/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/NastLen/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/NastLen/subscriptions',
#   'organizations_url': 'https://api.github.com/users/NastLen/orgs',
#   'repos_url': 'https://api.github.com/users/NastLen/repos',
#   'events_url': 'https://api.github.com/users/NastLen/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/NastLen/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'Adedipe23',
#   'id': 148863034,
#   'node_id': 'U_kgDOCN94Og',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/148863034?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Adedipe23',
#   'html_url': 'https://github.com/Adedipe23',
#   'followers_url': 'https://api.github.com/users/Adedipe23/followers',
#   'following_url': 'https://api.github.com/users/Adedipe23/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/Adedipe23/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/Adedipe23/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/Adedipe23/subscriptions',
#   'organizations_url': 'https://api.github.com/users/Adedipe23/orgs',
#   'repos_url': 'https://api.github.com/users/Adedipe23/repos',
#   'events_url': 'https://api.github.com/users/Adedipe23/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/Adedipe23/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'MohAli92',
#   'id': 148862863,
#   'node_id': 'U_kgDOCN93jw',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/148862863?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/MohAli92',
#   'html_url': 'https://github.com/MohAli92',
#   'followers_url': 'https://api.github.com/users/MohAli92/followers',
#   'following_url': 'https://api.github.com/users/MohAli92/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/MohAli92/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/MohAli92/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/MohAli92/subscriptions',
#   'organizations_url': 'https://api.github.com/users/MohAli92/orgs',
#   'repos_url': 'https://api.github.com/users/MohAli92/repos',
#   'events_url': 'https://api.github.com/users/MohAli92/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/MohAli92/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'Anukuga',
#   'id': 74722296,
#   'node_id': 'MDQ6VXNlcjc0NzIyMjk2',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/74722296?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Anukuga',
#   'html_url': 'https://github.com/Anukuga',
#   'followers_url': 'https://api.github.com/users/Anukuga/followers',
#   'following_url': 'https://api.github.com/users/Anukuga/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/Anukuga/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/Anukuga/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/Anukuga/subscriptions',
#   'organizations_url': 'https://api.github.com/users/Anukuga/orgs',
#   'repos_url': 'https://api.github.com/users/Anukuga/repos',
#   'events_url': 'https://api.github.com/users/Anukuga/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/Anukuga/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'ahmedshh',
#   'id': 148863322,
#   'node_id': 'U_kgDOCN95Wg',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/148863322?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/ahmedshh',
#   'html_url': 'https://github.com/ahmedshh',
#   'followers_url': 'https://api.github.com/users/ahmedshh/followers',
#   'following_url': 'https://api.github.com/users/ahmedshh/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/ahmedshh/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/ahmedshh/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/ahmedshh/subscriptions',
#   'organizations_url': 'https://api.github.com/users/ahmedshh/orgs',
#   'repos_url': 'https://api.github.com/users/ahmedshh/repos',
#   'events_url': 'https://api.github.com/users/ahmedshh/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/ahmedshh/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'juanchoupegui',
#   'id': 148862881,
#   'node_id': 'U_kgDOCN93oQ',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/148862881?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/juanchoupegui',
#   'html_url': 'https://github.com/juanchoupegui',
#   'followers_url': 'https://api.github.com/users/juanchoupegui/followers',
#   'following_url': 'https://api.github.com/users/juanchoupegui/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/juanchoupegui/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/juanchoupegui/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/juanchoupegui/subscriptions',
#   'organizations_url': 'https://api.github.com/users/juanchoupegui/orgs',
#   'repos_url': 'https://api.github.com/users/juanchoupegui/repos',
#   'events_url': 'https://api.github.com/users/juanchoupegui/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/juanchoupegui/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'kseniiavi',
#   'id': 148862913,
#   'node_id': 'U_kgDOCN93wQ',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/148862913?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/kseniiavi',
#   'html_url': 'https://github.com/kseniiavi',
#   'followers_url': 'https://api.github.com/users/kseniiavi/followers',
#   'following_url': 'https://api.github.com/users/kseniiavi/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/kseniiavi/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/kseniiavi/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/kseniiavi/subscriptions',
#   'organizations_url': 'https://api.github.com/users/kseniiavi/orgs',
#   'repos_url': 'https://api.github.com/users/kseniiavi/repos',
#   'events_url': 'https://api.github.com/users/kseniiavi/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/kseniiavi/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'SinaNajafi1',
#   'id': 148863702,
#   'node_id': 'U_kgDOCN961g',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/148863702?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/SinaNajafi1',
#   'html_url': 'https://github.com/SinaNajafi1',
#   'followers_url': 'https://api.github.com/users/SinaNajafi1/followers',
#   'following_url': 'https://api.github.com/users/SinaNajafi1/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/SinaNajafi1/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/SinaNajafi1/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/SinaNajafi1/subscriptions',
#   'organizations_url': 'https://api.github.com/users/SinaNajafi1/orgs',
#   'repos_url': 'https://api.github.com/users/SinaNajafi1/repos',
#   'events_url': 'https://api.github.com/users/SinaNajafi1/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/SinaNajafi1/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'Whyteman95',
#   'id': 148862892,
#   'node_id': 'U_kgDOCN93rA',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/148862892?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Whyteman95',
#   'html_url': 'https://github.com/Whyteman95',
#   'followers_url': 'https://api.github.com/users/Whyteman95/followers',
#   'following_url': 'https://api.github.com/users/Whyteman95/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/Whyteman95/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/Whyteman95/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/Whyteman95/subscriptions',
#   'organizations_url': 'https://api.github.com/users/Whyteman95/orgs',
#   'repos_url': 'https://api.github.com/users/Whyteman95/repos',
#   'events_url': 'https://api.github.com/users/Whyteman95/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/Whyteman95/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'Maryem29',
#   'id': 148862796,
#   'node_id': 'U_kgDOCN93TA',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/148862796?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Maryem29',
#   'html_url': 'https://github.com/Maryem29',
#   'followers_url': 'https://api.github.com/users/Maryem29/followers',
#   'following_url': 'https://api.github.com/users/Maryem29/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/Maryem29/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/Maryem29/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/Maryem29/subscriptions',
#   'organizations_url': 'https://api.github.com/users/Maryem29/orgs',
#   'repos_url': 'https://api.github.com/users/Maryem29/repos',
#   'events_url': 'https://api.github.com/users/Maryem29/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/Maryem29/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'yashar2028',
#   'id': 148863523,
#   'node_id': 'U_kgDOCN96Iw',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/148863523?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/yashar2028',
#   'html_url': 'https://github.com/yashar2028',
#   'followers_url': 'https://api.github.com/users/yashar2028/followers',
#   'following_url': 'https://api.github.com/users/yashar2028/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/yashar2028/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/yashar2028/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/yashar2028/subscriptions',
#   'organizations_url': 'https://api.github.com/users/yashar2028/orgs',
#   'repos_url': 'https://api.github.com/users/yashar2028/repos',
#   'events_url': 'https://api.github.com/users/yashar2028/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/yashar2028/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'Oscarkyamuwendo',
#   'id': 148862985,
#   'node_id': 'U_kgDOCN94CQ',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/148862985?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Oscarkyamuwendo',
#   'html_url': 'https://github.com/Oscarkyamuwendo',
#   'followers_url': 'https://api.github.com/users/Oscarkyamuwendo/followers',
#   'following_url': 'https://api.github.com/users/Oscarkyamuwendo/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/Oscarkyamuwendo/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/Oscarkyamuwendo/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/Oscarkyamuwendo/subscriptions',
#   'organizations_url': 'https://api.github.com/users/Oscarkyamuwendo/orgs',
#   'repos_url': 'https://api.github.com/users/Oscarkyamuwendo/repos',
#   'events_url': 'https://api.github.com/users/Oscarkyamuwendo/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/Oscarkyamuwendo/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'Tabs208',
#   'id': 128395394,
#   'node_id': 'U_kgDOB6cogg',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/128395394?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Tabs208',
#   'html_url': 'https://github.com/Tabs208',
#   'followers_url': 'https://api.github.com/users/Tabs208/followers',
#   'following_url': 'https://api.github.com/users/Tabs208/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/Tabs208/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/Tabs208/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/Tabs208/subscriptions',
#   'organizations_url': 'https://api.github.com/users/Tabs208/orgs',
#   'repos_url': 'https://api.github.com/users/Tabs208/repos',
#   'events_url': 'https://api.github.com/users/Tabs208/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/Tabs208/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'prity007',
#   'id': 148862870,
#   'node_id': 'U_kgDOCN93lg',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/148862870?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/prity007',
#   'html_url': 'https://github.com/prity007',
#   'followers_url': 'https://api.github.com/users/prity007/followers',
#   'following_url': 'https://api.github.com/users/prity007/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/prity007/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/prity007/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/prity007/subscriptions',
#   'organizations_url': 'https://api.github.com/users/prity007/orgs',
#   'repos_url': 'https://api.github.com/users/prity007/repos',
#   'events_url': 'https://api.github.com/users/prity007/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/prity007/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'Boves556',
#   'id': 148862792,
#   'node_id': 'U_kgDOCN93SA',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/148862792?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Boves556',
#   'html_url': 'https://github.com/Boves556',
#   'followers_url': 'https://api.github.com/users/Boves556/followers',
#   'following_url': 'https://api.github.com/users/Boves556/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/Boves556/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/Boves556/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/Boves556/subscriptions',
#   'organizations_url': 'https://api.github.com/users/Boves556/orgs',
#   'repos_url': 'https://api.github.com/users/Boves556/repos',
#   'events_url': 'https://api.github.com/users/Boves556/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/Boves556/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'BAMMEZ',
#   'id': 148863133,
#   'node_id': 'U_kgDOCN94nQ',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/148863133?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/BAMMEZ',
#   'html_url': 'https://github.com/BAMMEZ',
#   'followers_url': 'https://api.github.com/users/BAMMEZ/followers',
#   'following_url': 'https://api.github.com/users/BAMMEZ/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/BAMMEZ/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/BAMMEZ/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/BAMMEZ/subscriptions',
#   'organizations_url': 'https://api.github.com/users/BAMMEZ/orgs',
#   'repos_url': 'https://api.github.com/users/BAMMEZ/repos',
#   'events_url': 'https://api.github.com/users/BAMMEZ/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/BAMMEZ/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'chiwuba',
#   'id': 58079090,
#   'node_id': 'MDQ6VXNlcjU4MDc5MDkw',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/58079090?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/chiwuba',
#   'html_url': 'https://github.com/chiwuba',
#   'followers_url': 'https://api.github.com/users/chiwuba/followers',
#   'following_url': 'https://api.github.com/users/chiwuba/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/chiwuba/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/chiwuba/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/chiwuba/subscriptions',
#   'organizations_url': 'https://api.github.com/users/chiwuba/orgs',
#   'repos_url': 'https://api.github.com/users/chiwuba/repos',
#   'events_url': 'https://api.github.com/users/chiwuba/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/chiwuba/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'dominikb1888',
#   'id': 289612,
#   'node_id': 'MDQ6VXNlcjI4OTYxMg==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/289612?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/dominikb1888',
#   'html_url': 'https://github.com/dominikb1888',
#   'followers_url': 'https://api.github.com/users/dominikb1888/followers',
#   'following_url': 'https://api.github.com/users/dominikb1888/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/dominikb1888/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/dominikb1888/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/dominikb1888/subscriptions',
#   'organizations_url': 'https://api.github.com/users/dominikb1888/orgs',
#   'repos_url': 'https://api.github.com/users/dominikb1888/repos',
#   'events_url': 'https://api.github.com/users/dominikb1888/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/dominikb1888/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'AmaAdusei',
#   'id': 148862738,
#   'node_id': 'U_kgDOCN93Eg',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/148862738?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/AmaAdusei',
#   'html_url': 'https://github.com/AmaAdusei',
#   'followers_url': 'https://api.github.com/users/AmaAdusei/followers',
#   'following_url': 'https://api.github.com/users/AmaAdusei/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/AmaAdusei/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/AmaAdusei/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/AmaAdusei/subscriptions',
#   'organizations_url': 'https://api.github.com/users/AmaAdusei/orgs',
#   'repos_url': 'https://api.github.com/users/AmaAdusei/repos',
#   'events_url': 'https://api.github.com/users/AmaAdusei/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/AmaAdusei/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'udehadaeze',
#   'id': 148863379,
#   'node_id': 'U_kgDOCN95kw',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/148863379?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/udehadaeze',
#   'html_url': 'https://github.com/udehadaeze',
#   'followers_url': 'https://api.github.com/users/udehadaeze/followers',
#   'following_url': 'https://api.github.com/users/udehadaeze/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/udehadaeze/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/udehadaeze/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/udehadaeze/subscriptions',
#   'organizations_url': 'https://api.github.com/users/udehadaeze/orgs',
#   'repos_url': 'https://api.github.com/users/udehadaeze/repos',
#   'events_url': 'https://api.github.com/users/udehadaeze/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/udehadaeze/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'David001d',
#   'id': 148862921,
#   'node_id': 'U_kgDOCN93yQ',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/148862921?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/David001d',
#   'html_url': 'https://github.com/David001d',
#   'followers_url': 'https://api.github.com/users/David001d/followers',
#   'following_url': 'https://api.github.com/users/David001d/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/David001d/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/David001d/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/David001d/subscriptions',
#   'organizations_url': 'https://api.github.com/users/David001d/orgs',
#   'repos_url': 'https://api.github.com/users/David001d/repos',
#   'events_url': 'https://api.github.com/users/David001d/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/David001d/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'mdawoodaslam',
#   'id': 103655524,
#   'node_id': 'U_kgDOBi2oZA',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/103655524?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/mdawoodaslam',
#   'html_url': 'https://github.com/mdawoodaslam',
#   'followers_url': 'https://api.github.com/users/mdawoodaslam/followers',
#   'following_url': 'https://api.github.com/users/mdawoodaslam/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/mdawoodaslam/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/mdawoodaslam/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/mdawoodaslam/subscriptions',
#   'organizations_url': 'https://api.github.com/users/mdawoodaslam/orgs',
#   'repos_url': 'https://api.github.com/users/mdawoodaslam/repos',
#   'events_url': 'https://api.github.com/users/mdawoodaslam/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/mdawoodaslam/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'AngelinaNSS',
#   'id': 148863357,
#   'node_id': 'U_kgDOCN95fQ',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/148863357?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/AngelinaNSS',
#   'html_url': 'https://github.com/AngelinaNSS',
#   'followers_url': 'https://api.github.com/users/AngelinaNSS/followers',
#   'following_url': 'https://api.github.com/users/AngelinaNSS/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/AngelinaNSS/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/AngelinaNSS/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/AngelinaNSS/subscriptions',
#   'organizations_url': 'https://api.github.com/users/AngelinaNSS/orgs',
#   'repos_url': 'https://api.github.com/users/AngelinaNSS/repos',
#   'events_url': 'https://api.github.com/users/AngelinaNSS/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/AngelinaNSS/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'Nada1347',
#   'id': 148863210,
#   'node_id': 'U_kgDOCN946g',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/148863210?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Nada1347',
#   'html_url': 'https://github.com/Nada1347',
#   'followers_url': 'https://api.github.com/users/Nada1347/followers',
#   'following_url': 'https://api.github.com/users/Nada1347/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/Nada1347/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/Nada1347/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/Nada1347/subscriptions',
#   'organizations_url': 'https://api.github.com/users/Nada1347/orgs',
#   'repos_url': 'https://api.github.com/users/Nada1347/repos',
#   'events_url': 'https://api.github.com/users/Nada1347/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/Nada1347/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'NDYawt',
#   'id': 148863116,
#   'node_id': 'U_kgDOCN94jA',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/148863116?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/NDYawt',
#   'html_url': 'https://github.com/NDYawt',
#   'followers_url': 'https://api.github.com/users/NDYawt/followers',
#   'following_url': 'https://api.github.com/users/NDYawt/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/NDYawt/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/NDYawt/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/NDYawt/subscriptions',
#   'organizations_url': 'https://api.github.com/users/NDYawt/orgs',
#   'repos_url': 'https://api.github.com/users/NDYawt/repos',
#   'events_url': 'https://api.github.com/users/NDYawt/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/NDYawt/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'gansah1',
#   'id': 148863777,
#   'node_id': 'U_kgDOCN97IQ',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/148863777?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/gansah1',
#   'html_url': 'https://github.com/gansah1',
#   'followers_url': 'https://api.github.com/users/gansah1/followers',
#   'following_url': 'https://api.github.com/users/gansah1/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/gansah1/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/gansah1/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/gansah1/subscriptions',
#   'organizations_url': 'https://api.github.com/users/gansah1/orgs',
#   'repos_url': 'https://api.github.com/users/gansah1/repos',
#   'events_url': 'https://api.github.com/users/gansah1/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/gansah1/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'GEORGEMUTALE',
#   'id': 148863672,
#   'node_id': 'U_kgDOCN96uA',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/148863672?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/GEORGEMUTALE',
#   'html_url': 'https://github.com/GEORGEMUTALE',
#   'followers_url': 'https://api.github.com/users/GEORGEMUTALE/followers',
#   'following_url': 'https://api.github.com/users/GEORGEMUTALE/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/GEORGEMUTALE/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/GEORGEMUTALE/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/GEORGEMUTALE/subscriptions',
#   'organizations_url': 'https://api.github.com/users/GEORGEMUTALE/orgs',
#   'repos_url': 'https://api.github.com/users/GEORGEMUTALE/repos',
#   'events_url': 'https://api.github.com/users/GEORGEMUTALE/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/GEORGEMUTALE/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'fisidinho25',
#   'id': 27904549,
#   'node_id': 'MDQ6VXNlcjI3OTA0NTQ5',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/27904549?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/fisidinho25',
#   'html_url': 'https://github.com/fisidinho25',
#   'followers_url': 'https://api.github.com/users/fisidinho25/followers',
#   'following_url': 'https://api.github.com/users/fisidinho25/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/fisidinho25/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/fisidinho25/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/fisidinho25/subscriptions',
#   'organizations_url': 'https://api.github.com/users/fisidinho25/orgs',
#   'repos_url': 'https://api.github.com/users/fisidinho25/repos',
#   'events_url': 'https://api.github.com/users/fisidinho25/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/fisidinho25/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'MeliseRocha',
#   'id': 127310708,
#   'node_id': 'U_kgDOB5abdA',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/127310708?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/MeliseRocha',
#   'html_url': 'https://github.com/MeliseRocha',
#   'followers_url': 'https://api.github.com/users/MeliseRocha/followers',
#   'following_url': 'https://api.github.com/users/MeliseRocha/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/MeliseRocha/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/MeliseRocha/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/MeliseRocha/subscriptions',
#   'organizations_url': 'https://api.github.com/users/MeliseRocha/orgs',
#   'repos_url': 'https://api.github.com/users/MeliseRocha/repos',
#   'events_url': 'https://api.github.com/users/MeliseRocha/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/MeliseRocha/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'safrinfaizz',
#   'id': 150972752,
#   'node_id': 'U_kgDOCP-pUA',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/150972752?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/safrinfaizz',
#   'html_url': 'https://github.com/safrinfaizz',
#   'followers_url': 'https://api.github.com/users/safrinfaizz/followers',
#   'following_url': 'https://api.github.com/users/safrinfaizz/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/safrinfaizz/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/safrinfaizz/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/safrinfaizz/subscriptions',
#   'organizations_url': 'https://api.github.com/users/safrinfaizz/orgs',
#   'repos_url': 'https://api.github.com/users/safrinfaizz/repos',
#   'events_url': 'https://api.github.com/users/safrinfaizz/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/safrinfaizz/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'Rhyan2',
#   'id': 148863405,
#   'node_id': 'U_kgDOCN95rQ',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/148863405?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Rhyan2',
#   'html_url': 'https://github.com/Rhyan2',
#   'followers_url': 'https://api.github.com/users/Rhyan2/followers',
#   'following_url': 'https://api.github.com/users/Rhyan2/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/Rhyan2/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/Rhyan2/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/Rhyan2/subscriptions',
#   'organizations_url': 'https://api.github.com/users/Rhyan2/orgs',
#   'repos_url': 'https://api.github.com/users/Rhyan2/repos',
#   'events_url': 'https://api.github.com/users/Rhyan2/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/Rhyan2/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'adamganiu11',
#   'id': 148863963,
#   'node_id': 'U_kgDOCN972w',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/148863963?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/adamganiu11',
#   'html_url': 'https://github.com/adamganiu11',
#   'followers_url': 'https://api.github.com/users/adamganiu11/followers',
#   'following_url': 'https://api.github.com/users/adamganiu11/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/adamganiu11/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/adamganiu11/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/adamganiu11/subscriptions',
#   'organizations_url': 'https://api.github.com/users/adamganiu11/orgs',
#   'repos_url': 'https://api.github.com/users/adamganiu11/repos',
#   'events_url': 'https://api.github.com/users/adamganiu11/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/adamganiu11/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'Heshamelmogy',
#   'id': 148863291,
#   'node_id': 'U_kgDOCN95Ow',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/148863291?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Heshamelmogy',
#   'html_url': 'https://github.com/Heshamelmogy',
#   'followers_url': 'https://api.github.com/users/Heshamelmogy/followers',
#   'following_url': 'https://api.github.com/users/Heshamelmogy/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/Heshamelmogy/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/Heshamelmogy/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/Heshamelmogy/subscriptions',
#   'organizations_url': 'https://api.github.com/users/Heshamelmogy/orgs',
#   'repos_url': 'https://api.github.com/users/Heshamelmogy/repos',
#   'events_url': 'https://api.github.com/users/Heshamelmogy/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/Heshamelmogy/received_events',
#   'type': 'User',
#   'site_admin': False}]

# %%
text = []
for author in author_data:
    name = author['login']
    img = author['avatar_url']
    url = author['html_url']
    text.append(f"[![{name}]({img})]({url})")

result = " ".join(text)
display(Markdown(result))
# Out:
# [![SenaDok](https://avatars.githubusercontent.com/u/148862726?v=4)](https://github.com/SenaDok) [![mohammadmasry](https://avatars.githubusercontent.com/u/148862917?v=4)](https://github.com/mohammadmasry) [![SuraniKrrish](https://avatars.githubusercontent.com/u/148862687?v=4)](https://github.com/SuraniKrrish) [![azukaegoo](https://avatars.githubusercontent.com/u/132351500?v=4)](https://github.com/azukaegoo) [![jysndabuio](https://avatars.githubusercontent.com/u/148863168?v=4)](https://github.com/jysndabuio) [![Jokestevens](https://avatars.githubusercontent.com/u/148862801?v=4)](https://github.com/Jokestevens) [![NastLen](https://avatars.githubusercontent.com/u/148862793?v=4)](https://github.com/NastLen) [![Adedipe23](https://avatars.githubusercontent.com/u/148863034?v=4)](https://github.com/Adedipe23) [![MohAli92](https://avatars.githubusercontent.com/u/148862863?v=4)](https://github.com/MohAli92) [![Anukuga](https://avatars.githubusercontent.com/u/74722296?v=4)](https://github.com/Anukuga) [![ahmedshh](https://avatars.githubusercontent.com/u/148863322?v=4)](https://github.com/ahmedshh) [![juanchoupegui](https://avatars.githubusercontent.com/u/148862881?v=4)](https://github.com/juanchoupegui) [![kseniiavi](https://avatars.githubusercontent.com/u/148862913?v=4)](https://github.com/kseniiavi) [![SinaNajafi1](https://avatars.githubusercontent.com/u/148863702?v=4)](https://github.com/SinaNajafi1) [![Whyteman95](https://avatars.githubusercontent.com/u/148862892?v=4)](https://github.com/Whyteman95) [![Maryem29](https://avatars.githubusercontent.com/u/148862796?v=4)](https://github.com/Maryem29) [![yashar2028](https://avatars.githubusercontent.com/u/148863523?v=4)](https://github.com/yashar2028) [![Oscarkyamuwendo](https://avatars.githubusercontent.com/u/148862985?v=4)](https://github.com/Oscarkyamuwendo) [![Tabs208](https://avatars.githubusercontent.com/u/128395394?v=4)](https://github.com/Tabs208) [![prity007](https://avatars.githubusercontent.com/u/148862870?v=4)](https://github.com/prity007) [![Boves556](https://avatars.githubusercontent.com/u/148862792?v=4)](https://github.com/Boves556) [![BAMMEZ](https://avatars.githubusercontent.com/u/148863133?v=4)](https://github.com/BAMMEZ) [![chiwuba](https://avatars.githubusercontent.com/u/58079090?v=4)](https://github.com/chiwuba) [![dominikb1888](https://avatars.githubusercontent.com/u/289612?v=4)](https://github.com/dominikb1888) [![AmaAdusei](https://avatars.githubusercontent.com/u/148862738?v=4)](https://github.com/AmaAdusei) [![udehadaeze](https://avatars.githubusercontent.com/u/148863379?v=4)](https://github.com/udehadaeze) [![David001d](https://avatars.githubusercontent.com/u/148862921?v=4)](https://github.com/David001d) [![mdawoodaslam](https://avatars.githubusercontent.com/u/103655524?v=4)](https://github.com/mdawoodaslam) [![AngelinaNSS](https://avatars.githubusercontent.com/u/148863357?v=4)](https://github.com/AngelinaNSS) [![Nada1347](https://avatars.githubusercontent.com/u/148863210?v=4)](https://github.com/Nada1347) [![NDYawt](https://avatars.githubusercontent.com/u/148863116?v=4)](https://github.com/NDYawt) [![gansah1](https://avatars.githubusercontent.com/u/148863777?v=4)](https://github.com/gansah1) [![GEORGEMUTALE](https://avatars.githubusercontent.com/u/148863672?v=4)](https://github.com/GEORGEMUTALE) [![fisidinho25](https://avatars.githubusercontent.com/u/27904549?v=4)](https://github.com/fisidinho25) [![MeliseRocha](https://avatars.githubusercontent.com/u/127310708?v=4)](https://github.com/MeliseRocha) [![safrinfaizz](https://avatars.githubusercontent.com/u/150972752?v=4)](https://github.com/safrinfaizz) [![Rhyan2](https://avatars.githubusercontent.com/u/148863405?v=4)](https://github.com/Rhyan2) [![adamganiu11](https://avatars.githubusercontent.com/u/148863963?v=4)](https://github.com/adamganiu11) [![Heshamelmogy](https://avatars.githubusercontent.com/u/148863291?v=4)](https://github.com/Heshamelmogy)
